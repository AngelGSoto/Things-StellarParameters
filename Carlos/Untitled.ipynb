# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('EfficiencyParameter_2023.csv')

# %%
df_ = df[0:20]
df_
# Out:
#    #Survey StarType Parameter             PredType      Score       Mean  \
# 0   Apogee    Giant      TEFF            RFpredict  90.768921   6.676254
# 1   Apogee    Giant      TEFF            NNpredict  90.416306 -12.897832
# 2   Apogee    Dwarf      TEFF            RFpredict  97.188234  -0.244522
# 3   Apogee    Dwarf      TEFF            NNpredict  97.185195 -16.936668
# 4   Apogee    Giant      LOGG            RFpredict  90.549362   0.003850
# 5   Apogee    Giant      LOGG       RFpredict_TEFF  90.480103   0.007747
# 6   Apogee    Giant      LOGG            NNpredict  91.444718   0.050117
# 7   Apogee    Giant      LOGG       NNpredict_TEFF  91.183021   0.003017
# 8   Apogee    Dwarf      LOGG            RFpredict  74.404350  -0.003202
# 9   Apogee    Dwarf      LOGG       RFpredict_TEFF  74.740976  -0.003235
# 10  Apogee    Dwarf      LOGG            NNpredict  76.236644   0.010400
# 11  Apogee    Dwarf      LOGG       NNpredict_TEFF  75.851871  -0.003838
# ...

# %%
if "RFpredict_TEFF_LOGG" in df_["PredType"].values:
    condition = df_["PredType"] == "RFpredict_TEFF_LOGG"
else:
    # If the condition is not met, you can use another condition or skip it
    condition = df_["PredType"] == "NNpredict"

df_msk = df_[condition]

# %%
df_msk
# Out:
#    #Survey StarType Parameter             PredType      Score      Mean  \
# 14  Apogee    Giant      FE_H  RFpredict_TEFF_LOGG  88.322688  0.005372
#
#     StdMean  StdABSMean    MinVal    MaxVal  NumObjects
# 14  0.15785     0.10761 -2.040311  0.252459      1097.0

# %%
# List of surveys and star types
surveys = ["Apogee", "Galah", "LamostMedium"]
star_types = ['Giant', 'Dwarf']

# Unique parameters from the DataFrame
parameters = np.unique(df["Parameter"])

# %%
# Assuming df is your DataFrame
df['PredType'] = df.apply(lambda row: 'RFpredict_TEFF_LOGG' if row['Parameter'] == 'TEFF' and row['PredType'] == 'RFpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'NNpredict_TEFF_LOGG' if row['Parameter'] == 'TEFF' and row['PredType'] == 'NNpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'RFpredict_TEFF_LOGG' if row['Parameter'] == 'Teff' and row['PredType'] == 'RFpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'NNpredict_TEFF_LOGG' if row['Parameter'] == 'Teff' and row['PredType'] == 'NNpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'RFpredict_TEFF_LOGG' if row['Parameter'] == 'teff_cnn' and row['PredType'] == 'RFpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'NNpredict_TEFF_LOGG' if row['Parameter'] == 'teff_cnn' and row['PredType'] == 'NNpredict' else row['PredType'], axis=1)

# Add similar lines for 'LOGG'
df['PredType'] = df.apply(lambda row: 'RFpredict_TEFF_LOGG' if row['Parameter'] == 'LOGG' and row['PredType'] == 'RFpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'NNpredict_TEFF_LOGG' if row['Parameter'] == 'LOGG' and row['PredType'] == 'NNpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'RFpredict_TEFF_LOGG' if row['Parameter'] == 'logg' and row['PredType'] == 'RFpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'NNpredict_TEFF_LOGG' if row['Parameter'] == 'logg' and row['PredType'] == 'NNpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'RFpredict_TEFF_LOGG' if row['Parameter'] == 'logg_cnn' and row['PredType'] == 'RFpredict' else row['PredType'], axis=1)
df['PredType'] = df.apply(lambda row: 'NNpredict_TEFF_LOGG' if row['Parameter'] == 'logg_cnn' and row['PredType'] == 'NNpredict' else row['PredType'], axis=1)

# %%
df
# Out:
#           #Survey StarType Parameter             PredType      Score  \
# 0          Apogee    Giant      TEFF  RFpredict_TEFF_LOGG  90.768921
# 1          Apogee    Giant      TEFF  NNpredict_TEFF_LOGG  90.416306
# 2          Apogee    Dwarf      TEFF  RFpredict_TEFF_LOGG  97.188234
# 3          Apogee    Dwarf      TEFF  NNpredict_TEFF_LOGG  97.185195
# 4          Apogee    Giant      LOGG  RFpredict_TEFF_LOGG  90.549362
# ..            ...      ...       ...                  ...        ...
# 549  LamostMedium    Giant     ni_fe            NNpredict  39.454218
# 550  LamostMedium    Dwarf     ni_fe            RFpredict  25.106672
# 551  LamostMedium    Dwarf     ni_fe       RFpredict_TEFF  38.515816
# 552  LamostMedium    Dwarf     ni_fe  RFpredict_TEFF_LOGG  56.610666
# 553  LamostMedium    Dwarf     ni_fe            NNpredict  18.427019
#
#           Mean     StdMean  StdABSMean       MinVal       MaxVal  NumObjects
# ...

# %%
if "NNpredict_TEFF_LOGG" in df["PredType"].values:
    conditionNN = df["PredType"] == "NNpredict_TEFF_LOGG"
else:
    # If not, use "NNpredict"
    conditionNN = df["PredType"] == "NNpredict"

if "RFpredict_TEFF_LOGG" in df["PredType"].values:
    conditionRF = df["PredType"] == "RFpredict_TEFF_LOGG"
else:
    # If not, use "NNpredict"
    conditionRF = df["PredType"] == "RFpredict"

# %%
subset_NN_df = df[conditionNN]

# %%
subset_NN_df
# Out:
#           #Survey StarType Parameter             PredType      Score  \
# 1          Apogee    Giant      TEFF  NNpredict_TEFF_LOGG  90.416306
# 3          Apogee    Dwarf      TEFF  NNpredict_TEFF_LOGG  97.185195
# 6          Apogee    Giant      LOGG  NNpredict_TEFF_LOGG  91.444718
# 10         Apogee    Dwarf      LOGG  NNpredict_TEFF_LOGG  76.236644
# 17         Apogee    Giant      FE_H  NNpredict_TEFF_LOGG  91.896758
# ..            ...      ...       ...                  ...        ...
# 363         Galah    Giant   [Mg/Fe]  NNpredict_TEFF_LOGG  26.100844
# 481  LamostMedium    Giant  teff_cnn  NNpredict_TEFF_LOGG  65.433431
# 483  LamostMedium    Dwarf  teff_cnn  NNpredict_TEFF_LOGG  92.447019
# 486  LamostMedium    Giant  logg_cnn  NNpredict_TEFF_LOGG  76.725234
# 489  LamostMedium    Dwarf  logg_cnn  NNpredict_TEFF_LOGG  82.065993
#
#           Mean     StdMean  StdABSMean       MinVal       MaxVal  NumObjects
# ...

# %%
np.unique(df["Parameter"])
# Out:
# array(['ALPHA_M', 'AL_FE', 'CA_FE', 'CE_FE', 'CI_FE', 'CO_FE', 'CR_FE',
#        'C_FE', 'FE_H', 'K_FE', 'LOGG', 'MG_FE', 'MN_FE', 'NA_FE', 'NI_FE',
#        'N_FE', 'O_FE', 'SI_FE', 'TEFF', 'TIII_FE', 'TI_FE', 'Teff',
#        'V_FE', '[Al/Fe]', '[C/Fe]', '[Ca/Fe]', '[Co/Fe]', '[Cr/Fe]',
#        '[Cu/Fe]', '[Fe/H]', '[K/Fe]', '[Li/Fe]', '[Mg/Fe]', '[Mn/Fe]',
#        '[Na/Fe]', '[Ni/Fe]', '[O/Fe]', '[Sc/Fe]', '[Si/Fe]', '[Ti/Fe]',
#        '[Ti2/Fe]', '[Y/Fe]', '[Zn/Fe]', '[alpha/Fe]', 'alpha_m_cnn',
#        'c_fe', 'ca_fe', 'feh_cnn', 'logg', 'logg_cnn', 'mg_fe', 'n_fe',
#        'ni_fe', 'si_fe', 'teff_cnn'], dtype=object)
